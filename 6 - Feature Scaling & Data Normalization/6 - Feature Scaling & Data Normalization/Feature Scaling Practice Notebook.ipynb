# %% [markdown]
# # Feature Scaling Solution Notebook

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Importing Dataset

# %%
df = pd.read_csv("Dataset_03.csv")
df.head(15)
# Out:
#     Australia  Canada  Dubai  USA  Salary  YearsExperience  Purchased
# 0           0       0      1    0   39343              1.1          0
# 1           0       1      0    0   46205              1.3          1
# 2           0       1      0    0   37731              1.5          0
# 3           0       1      0    0   43525              2.0          0
# 4           0       0      0    1   39891              2.2          0
# 5           0       0      1    0   56642              2.9          0
# 6           0       1      0    0   60150              3.0          1
# 7           1       0      0    0   54445              3.2          0
# 8           0       0      1    0   64445              3.2          1
# 9           0       0      1    0   57189              3.7          0
# 10          0       0      1    0   63218              3.9          1
# 11          0       0      0    1   55794              4.0          0
# 12          0       0      1    0   56957              4.0          1
# 13          0       1      0    0   57081              4.1          0
# 14          1       0      0    0   61111              4.5          0

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %% [markdown]
# ### Splitting Dataset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =train_test_split(X, y, test_size = 0.2, random_state = 1)

# %% [markdown]
# ### Perform Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

# StandardScaler instance
sc = StandardScaler()

# Scaling the data (for numpy arrays, use slicing)
X_train[:, 4:] = sc.fit_transform(X_train[:, 4:])
X_test[:, 4:] = sc.transform(X_test[:, 4:])

# %% [markdown]
# ### Check it

# %%
X_train
# Out:
# array([[ 0.        ,  0.        ,  1.        ,  0.        ,  1.4613054 ,
#          1.39108016],
#        [ 0.        ,  1.        ,  0.        ,  0.        , -1.06760255,
#         -1.05896317],
#        [ 0.        ,  0.        ,  1.        ,  0.        ,  1.20174835,
#          1.1297422 ],
#        [ 1.        ,  0.        ,  0.        ,  0.        ,  0.92184131,
#          0.86840425],
#        [ 1.        ,  0.        ,  0.        ,  0.        ,  1.35259996,
#          0.96640598],
#        [ 0.        ,  0.        ,  0.        ,  1.        , -1.1927326 ,
#         -0.99362869],
#        [ 0.        ,  1.        ,  0.        ,  0.        , -1.2671082 ,
#         -1.2222994 ],
#        [ 1.        ,  0.        ,  0.        ,  0.        ,  1.06921517,
#          1.22774394],
#        [ 0.        ,  1.        ,  0.        ,  0.        , -0.4951515 ,
#         -0.73229073],
#        [ 1.        ,  0.        ,  0.        ,  0.        ,  0.23527882,
#          0.21505936],
#        [ 0.        ,  1.        ,  0.        ,  0.        , -0.60082683,
#         -0.37295104],
#        [ 1.        ,  0.        ,  0.        ,  0.        , -0.6915926 ,
#         -0.66695624],
#        [ 0.        ,  0.        ,  0.        ,  1.        ,  1.31207215,
#          1.4237474 ],
#        [ 0.        ,  1.        ,  0.        ,  0.        , -0.97532172,
#         -1.28763389],
#        [ 0.        ,  0.        ,  0.        ,  1.        , -0.29271904,
#         -0.0462786 ],
#        [ 0.        ,  0.        ,  1.        ,  0.        , -1.21160197,
#         -1.35296837],
#        [ 0.        ,  0.        ,  0.        ,  1.        , -0.22698617,
#         -0.11161309],
#        [ 0.        ,  1.        ,  0.        ,  0.        ,  1.63013111,
#          1.7177526 ],
#        [ 0.        ,  0.        ,  0.        ,  1.        ,  1.64800192,
#          1.65241812],
#        [ 0.        ,  0.        ,  1.        ,  0.        , -0.59710805,
#         -0.50362002],
#        [ 0.        ,  0.        ,  1.        ,  0.        , -0.34726114,
#         -0.66695624],
#        [ 0.        ,  0.        ,  1.        ,  0.        , -0.60509654,
#         -0.40561829],
#        [ 0.        ,  0.        ,  0.        ,  1.        , -0.64514229,
#         -0.40561829],
#        [ 0.        ,  0.        ,  1.        ,  0.        , -0.61594298,
#         -0.76495797]])

# %%
X_test
# Out:
# array([[ 0.        ,  1.        ,  0.        ,  0.        ,  0.29467599,
#          0.01905589],
#        [ 1.        ,  0.        ,  0.        ,  0.        ,  0.81754331,
#          0.60706629],
#        [ 0.        ,  0.        ,  1.        ,  0.        , -0.38951061,
#         -0.43828553],
#        [ 0.        ,  1.        ,  0.        ,  0.        ,  0.66834449,
#          0.2477266 ],
#        [ 1.        ,  0.        ,  0.        ,  0.        , -0.46206125,
#         -0.24228206],
#        [ 0.        ,  1.        ,  0.        ,  0.        ,  0.5925227 ,
#          0.50906456]])
